# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import pandas_datareader.data as pdr
import yfinance as yf

# Definir o período de tempo
start_date = datetime(2023, 1, 1)
end_date = datetime(2023, 12, 31)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime, timedelta
import pandas_datareader.data as pdr
import yfinance as yf

data_inicial = datetime.now() - timedelta(days=360)
data_final = datetime.now()

df_ibov = yf.download(['^BVSP'], start=data_inicial, end=data_final)['Adj Close']

df_ibov
# Out:
# [*********************100%***********************]  1 of 1 completed
# Date
# 2023-09-04    117777.00000
# 2023-09-05    117331.00000
# 2023-09-06    115985.00000
# 2023-09-08    115313.00000
# 2023-09-11    116883.00000
#                   ...
# 2024-08-21    136464.00000
# 2024-08-22    135173.00000
# 2024-08-23    135608.00000
# 2024-08-26    136889.00000
# 2024-08-27    136775.90625
# Name: Adj Close, Length: 245, dtype: float64

# %% [markdown]
# ### Análisando o Gráfico

# %%
retorno = df_ibov.iloc[-1] / df_ibov.iloc[0] - 1
print(f"O retorno foi: {retorno:.1%}")
# Out:
# O retorno foi: 16.1%

# %% [markdown]
# ### Retorno indice Ibovespa

# %%
# Exemplo de plotagem dos dados de fechamento
df_ibov.plot()
plt.show()
